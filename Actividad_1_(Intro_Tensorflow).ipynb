# %% [markdown]
# <a href="https://colab.research.google.com/github/jorgecote/seminario_profesional/blob/main/Actividad_1_(Intro_Tensorflow).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Actividad 1: Introducción a TensorFlow
#
# En esta actividad usted tendrá su primera aproximación al uso de TensorFlow y aprender como puede ser usado para solucionar problemas de machine learning. Corra las celdas de codigo del presente archivo. En algunas de las celdas encontrará bloques ***HACER*** siga las instrucciones para completar el código y ejecuta las eldas para ir continuando
#
# ## Instalación tensorflow
#
# TensorFlow es una biblioteca de software ampliamente utilizada en aprendizaje automático. Aquí aprenderemos cómo se representan los cálculos y las ventajas en el manejo de grandes volumenes de datos. Para todas las actividades de este archivo, usaremos la última versión de TensorFlow, TensorFlow 2, que ofrece una gran flexibilidad y la capacidad de ejecutar operaciones de manera imperativa, como en Python. Notarás que TensorFlow 2 es bastante similar a Python en su sintaxis y ejecución imperativa.

# %%
# Verificando versión de TensorFlow

import tensorflow as tf

print("Versión de TensorFlow:", tf.__version__)
# Out:
# Versión de TensorFlow: 2.15.0

# %% [markdown]
# En caso de requerir la instalación, Tensorflow ofrece la información necesaria en su [documentación](https://www.tensorflow.org/install?hl=es-419)

# %% [markdown]
# ## 1.1 Por qué TensorFlow se llama Tensorflow?
#
# TensorFlow se llama 'TensorFlow' porque maneja el flujo (nodo/operación matemática) de tensores, que son estructuras de datos que se pueden considerar como matrices multidimensionales. Los tensores se representan como matrices de n dimensiones de tipos de datos básicos, como una cadena o un número entero; proporcionan una manera de generalizar vectores y matrices a dimensiones superiores.
#
# La forma ```shape``` de un Tensor define su número de dimensiones y el tamaño de cada dimensión. El rango ```rank``` de un tensor proporciona el número de dimensiones (n-dimensiones); también puedes considerarlo como el orden o grado del tensor.
#
# Veamos primero los tensores 0-d, de los cuales un escalar es un ejemplo:

# %%
sport = tf.constant("Tennis", tf.string)
number = tf.constant(1.41421356237, tf.float64)

print("`sport` es un {}-d Tensor".format(tf.rank(sport).numpy()))
print("`number` es un {}-d Tensor".format(tf.rank(number).numpy()))

# %% [markdown]
# Se pueden utilizar vectores y listas para crear tensores unidimensionales:

# %%
'''HACER: Defina un Tensor 2-d de tipo string con 2 nombres de deportes'''
sports =      #HACER
'''HACER: Defina un Tensor 2-d de tipo float con los numeros pi, e y raíz de 2'''
numbers =     #HACER

print("`sports` es un {}-d Tensor con tamaño: {}".format(tf.rank(sports).numpy(), tf.shape(sports)))
print("`numbers` es un {}-d Tensor con tamaño: {}".format(tf.rank(numbers).numpy(), tf.shape(numbers)))

# %% [markdown]
# A continuación, consideramos la creación de tensores bidimensionales (es decir, matrices) y de rango superior. Por ejemplo, en futuras actividades que involucren procesamiento de imágenes y visión por computadora, usaremos tensores 4-d. Aquí las dimensiones corresponden a la cantidad de imágenes de ejemplo en nuestro lote, la altura de la imagen, el ancho de la imagen y la cantidad de canales de color.

# %%
### Definiendo tensores de alto orden ###

'''HACER: Definir un Tensor 2-d 2x3 que contenga números consecutivos'''
matrix =    # HACER

assert isinstance(matrix, tf.Tensor), "la matriz debe ser un objeto Tensor tf"
assert tf.rank(matrix).numpy() == 2

# %%
'''HACER: Definir un Tensor 4-d  Tensor.'''
# Use tf.zeros para inicializar un Tensor 4-d de zeros con tamaño 10 x 256 x 256 x 3.
#   Por ejemplo estas dimensiones podrían representar 10 imagenes donde cada imagen es RGB 256 x 256.

images =     # HACER

assert isinstance(images, tf.Tensor), "la matriz debe ser un objeto Tensor tf"
assert tf.rank(images).numpy() == 4, "la matriz debe ser de rango 4"
assert tf.shape(images).numpy().tolist() == [10, 256, 256, 3], "la matriz tiene tamaño incorrecto"

# %% [markdown]
# Como has visto, la forma de un tensor proporciona la cantidad de elementos en cada dimensión del tensor. La forma es bastante útil y la usaremos con frecuencia. También puedes usar el corte para acceder a subtensores dentro de un tensor de rango superior:

# %%
row_vector = matrix[1]
column_vector = matrix[:,1]
scalar = matrix[0, 1]

print("`row_vector`: {}".format(row_vector.numpy()))
print("`column_vector`: {}".format(column_vector.numpy()))
print("`scalar`: {}".format(scalar.numpy()))

# %% [markdown]
# ## 1.2 Operaciones con tensores
#
# Tensorflow soporta difernetes operaciones entre tensores ya sea sobreescribiendo el operador o utilizando los métodos nativos.

# %%
# Crear 1 tensor de rango 1 con números aleatorios  que contenga 50 valores

X =       # HACER

# Calcule la desviación estandar y la media del tensor sin utilizar los métodos directos para este fin
# Solamente utilice métodos u operaciones básicas suma, resta, multiplicación, división, potenciación, etc

media =         # HACER

desv =          # HACER

# %% [markdown]
# Una forma conveniente de pensar y visualizar cálculos en TensorFlow es en términos de gráficos. Podemos definir este gráfico en términos de tensores, que contienen datos, y las operaciones matemáticas que actúan sobre estos tensores en algún orden. Veamos un ejemplo simple y definamos este cálculo usando TensorFlow:
#
#
# ![image.png](data:image/png;base64,...)

# %%
# Crear los nodos en la gráfica e inicialice los valores
a = tf.constant(15)
b = tf.constant(61)

# Súmelos!
c1 = tf.add(a,b)
c2 = a + b # TensorFlow sobreescribe la operación "+" tal que funcione para los tensores
print(c1)
print(c2)

# %% [markdown]
# Observe cómo hemos creado un gráfico de cálculo que consta de operaciones de TensorFlow y cómo la salida es un tensor con valor 76; acabamos de crear un gráfico de cálculo que consta de operaciones, las ejecutó y nos devolvió el resultado.
#
# Ahora consideremos un ejemplo un poco más complicado:
#
# ![image.png](data:image/png;base64,...)
#
# Aquí, tomamos dos entradas, a, b, y calculamos una salida e. Cada nodo en el gráfico representa una operación que toma alguna entrada, realiza algún cálculo y pasa su salida a otro nodo.
#
# Definamos una función simple en TensorFlow para construir esta función de cálculo:

# %%
from tensorflow.python.ops.math_ops import subtract
### Definiendo cálculos con Tensores ###

# Construya una función con los cálculos
def func(a,b):
  '''HACER: Defina las operaciones para c, d, e. (Utilice las funciones nativas de tensorflow).'''
  c =      # HACER
  d =      # HACER
  e =      # HACER
  return e

# %% [markdown]
# Ahora, podemos llamar a esta función para ejecutar el cálculo del gráfico dadas algunas entradas a,b:

# %%
# Inicializando valores
a, b = 1.5, 2.5
# Ejecutar el cálculo
e_out = func(a,b)
print(e_out)

# %% [markdown]
# Observe cómo nuestra salida es un tensor con un valor definido por la salida del cálculo, y que la salida no tiene forma ya que es un valor escalar único.

# %% [markdown]
# ## 1.3 Creación de modelos
#
# En TensorFlow los cálculos pueden organizarse dentro de un modelo

# %%
### Construyendo un modelo para calcular el gráfico ###


class MyModel(tf.Module):
  def __init__(self, **kwargs):
    super().__init__(**kwargs)

    self.a = tf.constant(0.0)
    self.b = tf.constant(0.0)

  def __call__(self, x):
'''HACER: Defina las operaciones para c, d, e que ejecutara el modelo. (Utilice las funciones nativas de tensorflow).'''

    c=      # HACER
    d=      # HACER

    return e

# %%
model = MyModel()      # Se crea instancia del modelo
'''HACER: Ejecute el modelo con las mismas entradas del caso anterior e imprima la salida.'''
out =             # HACER

print("Salida:", out)
